# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np # linear algebra
url = "https://storage.googleapis.com/kagglesdsdata/datasets/3360797/5845248/Salary%20Data.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20250419%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250419T160559Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."

df = pd.read_csv(url)

print(df.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.shape
# Out:
# (30, 2)

# %%
df.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# #### Now lets find the corelation between the two variables using a heatmap

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# #### Now lets find the linear relationship between the two using a scatter plot

# %%
plt.scatter(df.YearsExperience,df.Salary,color="g",marker="*")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("")
plt.show()

# %% [markdown]
# #### Now we have split the data into x and y

# %%
x=df.iloc[:,:-1]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
print(x)
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y=df.iloc[:,1]
type(y)
# Out:
# pandas.core.series.Series

# %%
print(y)
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Now lets split the dataset into train and test dataset

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (21, 1)
# (9, 1)
# (21,)
# (9,)

# %% [markdown]
# #### Now lets create and fit the model

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_test)
y_predict
# Out:
# array([112456.08450188,  56455.21351165,  65145.00383772, 126939.06837866,
#         91214.37481593,  83490.11674831, 118249.27805259,  69007.13287153,
#         82524.58448986])

# %%
x_predict=model.predict(x_train)
x_predict
# Out:
# array([ 36179.03608415,  72869.26190533,  94110.97159128, 109559.48772652,
#         53558.61673629,  56455.21351165,  40041.16511796,  44868.82641022,
#         46799.89092712,  63213.93932081, 125008.00386176,  38110.10060105,
#         64179.47157926,  74800.32642224, 117283.74579414,  64179.47157926,
#         76731.39093914, 104731.82643426, 101835.2296589 ,  61282.87480391,
#         54524.14899474])

# %% [markdown]
# #### Now lets create a Data Frame for the actual & Predicted

# %%
new_df=pd.DataFrame({"Actual":y_test,"Predict":y_predict})
new_df
# Out:
#       Actual        Predict
# 25  105582.0  112456.084502
# 7    54445.0   56455.213512
# 13   57081.0   65145.003838
# 29  121872.0  126939.068379
# 20   91738.0   91214.374816
# 19   93940.0   83490.116748
# 27  112635.0  118249.278053
# 14   61111.0   69007.132872
# 18   81363.0   82524.584490

# %% [markdown]
# ### Now lets visualize the test and train data

# %%
plt.scatter(x_train,y_train,color="r",marker="*")
#plt.plot(x_train,y_predict,color="b")
plt.title("Visualizing training dataset")
plt.show()

# %%
plt.scatter(x_test,y_test,color="r",marker="*")
#plt.plot(x_train,y_predict,color="b")
plt.title("Visualizing test dataset")
plt.show()

# %% [markdown]
# #### Now lets check the Score

# %%
model.score(x_train,y_train)*100
# Out:
# 95.95112253757657

# %%
model.score(x_test,y_test)*100
# Out:
# 92.98899970829555

# %% [markdown]
# #### Here the score is very good for both train and test data
#
# #### Now lets calculate the accuracy of the model

# %% [markdown]
#  - Mean Square Error

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_predict)
# Out:
# 38521098.90679281

# %%
np.sqrt(mean_squared_error(y_test,y_predict))
# Out:
# 6206.536788482995

# %% [markdown]
#  - Mean Absolute Error

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_predict)
# Out:
# 5295.652675515484

# %% [markdown]
#  - R2 Score

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_predict)*100
# Out:
# 92.98899970829555
